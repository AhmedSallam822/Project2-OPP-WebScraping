# %%
pip install request

# %%
import requests
import csv

# %% [markdown]
# ## Request Data From Web

# %%
response = requests.get("https://gorest.co.in/public-api/users?_format=json&access-token=H4lYmIGLXZkDlpy_w0ZVS5rgcpDXbN7fhRRy")

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"code":200,"meta":{"pagination":{"total":4202,"pages":211,"page":1,"limit":20}},"data":[{"id":4270,"name":"Aadinath Tandon","email":"tandon_aadinath@emmerich-leffler.name","gender":"female","status":"inactive"},{"id":4269,"name":"Deb Chopra","email":"deb_chopra@haag.info","gender":"female","status":"active"},{"id":4267,"name":"Dayaamay Agarwal","email":"agarwal_dayaamay@lubowitz-steuber.info","gender":"male","status":"active"},{"id":4266,"name":"Gurdev Verma","email":"verma_gurdev@deckow.info","gender":"male","status":"active"},{"id":4264,"name":"Chandrabhan Varrier","email":"varrier_chandrabhan@buckridge.org","gender":"male","status":"inactive"},{"id":4263,"name":"Gov. Aasa Johar","email":"gov_aasa_johar@jaskolski.name","gender":"female","status":"active"},{"id":4260,"name":"Chitrali Ahuja","email":"chitrali_ahuja@schulist-mitchell.io","gender":"male","status":"inactive"},{"id":4259,"name":"Jay Panicker","email":"jay_panicker@cartwright-wisozk.co","gender":"male","status":"inactive"},{"id":4257,"name":"Chidaakaash Asan","email":"chidaakaash_asan@hammes.info","gender":"female","status":"active"},{"id":4256,"name":"Giri Saini","email":"giri_saini@becker.org","gender":"female","status":"active"},{"id":4254,"name":"Brahmdev Khanna","email":"brahmdev_khanna@sawayn.org","gender":"female","status":"active"},{"id":4253,"name":"Sitara Pilla","email":"pilla_sitara@rempel.info","gender":"female","status":"inactive"},{"id":4252,"name":"Rep. Chandra Malik","email":"rep_malik_chandra@goyette-dickens.net","gender":"female","status":"inactive"},{"id":4251,"name":"Dhananjay Johar","email":"dhananjay_johar@ritchie.name","gender":"male","status":"inactive"},{"id":4250,"name":"Ameyatma Kocchar","email":"kocchar_ameyatma@borer-dicki.biz","gender":"female","status":"inactive"},{"id":4247,"name":"Chandira Singh","email":"chandira_singh@hoeger.name","gender":"female","status":"inactive"},{"id":4246,"name":"Sweta Namboothiri","email":"namboothiri_sweta@kessler.co","gender":"female","status":"inactive"},{"id":4245,"name":"Charak Khatri","email":"khatri_charak@berge.biz","gender":"male","status":"active"},{"id":4244,"name":"Sarala Mehrotra","email":"sarala_mehrotra@schuppe.name","gender":"female","status":"active"},{"id":4242,"name":"Som Mukhopadhyay","email":"som_mukhopadhyay@shanahan-spinka.org","gender":"female","status":"active"}]}'

# %% [markdown]
# ## Convert Data to Json Format

# %%
response.json()
# Out:
# {'code': 200,
#  'meta': {'pagination': {'total': 4202, 'pages': 211, 'page': 1, 'limit': 20}},
#  'data': [{'id': 4270,
#    'name': 'Aadinath Tandon',
#    'email': 'tandon_aadinath@emmerich-leffler.name',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4269,
#    'name': 'Deb Chopra',
#    'email': 'deb_chopra@haag.info',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4267,
#    'name': 'Dayaamay Agarwal',
#    'email': 'agarwal_dayaamay@lubowitz-steuber.info',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 4266,
#    'name': 'Gurdev Verma',
#    'email': 'verma_gurdev@deckow.info',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 4264,
#    'name': 'Chandrabhan Varrier',
#    'email': 'varrier_chandrabhan@buckridge.org',
#    'gender': 'male',
#    'status': 'inactive'},
#   {'id': 4263,
#    'name': 'Gov. Aasa Johar',
#    'email': 'gov_aasa_johar@jaskolski.name',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4260,
#    'name': 'Chitrali Ahuja',
#    'email': 'chitrali_ahuja@schulist-mitchell.io',
#    'gender': 'male',
#    'status': 'inactive'},
#   {'id': 4259,
#    'name': 'Jay Panicker',
#    'email': 'jay_panicker@cartwright-wisozk.co',
#    'gender': 'male',
#    'status': 'inactive'},
#   {'id': 4257,
#    'name': 'Chidaakaash Asan',
#    'email': 'chidaakaash_asan@hammes.info',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4256,
#    'name': 'Giri Saini',
#    'email': 'giri_saini@becker.org',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4254,
#    'name': 'Brahmdev Khanna',
#    'email': 'brahmdev_khanna@sawayn.org',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4253,
#    'name': 'Sitara Pilla',
#    'email': 'pilla_sitara@rempel.info',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4252,
#    'name': 'Rep. Chandra Malik',
#    'email': 'rep_malik_chandra@goyette-dickens.net',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4251,
#    'name': 'Dhananjay Johar',
#    'email': 'dhananjay_johar@ritchie.name',
#    'gender': 'male',
#    'status': 'inactive'},
#   {'id': 4250,
#    'name': 'Ameyatma Kocchar',
#    'email': 'kocchar_ameyatma@borer-dicki.biz',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4247,
#    'name': 'Chandira Singh',
#    'email': 'chandira_singh@hoeger.name',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4246,
#    'name': 'Sweta Namboothiri',
#    'email': 'namboothiri_sweta@kessler.co',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4245,
#    'name': 'Charak Khatri',
#    'email': 'khatri_charak@berge.biz',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 4244,
#    'name': 'Sarala Mehrotra',
#    'email': 'sarala_mehrotra@schuppe.name',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4242,
#    'name': 'Som Mukhopadhyay',
#    'email': 'som_mukhopadhyay@shanahan-spinka.org',
#    'gender': 'female',
#    'status': 'active'}]}

# %%
employees = response.json()
employees
# Out:
# {'code': 200,
#  'meta': {'pagination': {'total': 4202, 'pages': 211, 'page': 1, 'limit': 20}},
#  'data': [{'id': 4270,
#    'name': 'Aadinath Tandon',
#    'email': 'tandon_aadinath@emmerich-leffler.name',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4269,
#    'name': 'Deb Chopra',
#    'email': 'deb_chopra@haag.info',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4267,
#    'name': 'Dayaamay Agarwal',
#    'email': 'agarwal_dayaamay@lubowitz-steuber.info',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 4266,
#    'name': 'Gurdev Verma',
#    'email': 'verma_gurdev@deckow.info',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 4264,
#    'name': 'Chandrabhan Varrier',
#    'email': 'varrier_chandrabhan@buckridge.org',
#    'gender': 'male',
#    'status': 'inactive'},
#   {'id': 4263,
#    'name': 'Gov. Aasa Johar',
#    'email': 'gov_aasa_johar@jaskolski.name',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4260,
#    'name': 'Chitrali Ahuja',
#    'email': 'chitrali_ahuja@schulist-mitchell.io',
#    'gender': 'male',
#    'status': 'inactive'},
#   {'id': 4259,
#    'name': 'Jay Panicker',
#    'email': 'jay_panicker@cartwright-wisozk.co',
#    'gender': 'male',
#    'status': 'inactive'},
#   {'id': 4257,
#    'name': 'Chidaakaash Asan',
#    'email': 'chidaakaash_asan@hammes.info',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4256,
#    'name': 'Giri Saini',
#    'email': 'giri_saini@becker.org',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4254,
#    'name': 'Brahmdev Khanna',
#    'email': 'brahmdev_khanna@sawayn.org',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4253,
#    'name': 'Sitara Pilla',
#    'email': 'pilla_sitara@rempel.info',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4252,
#    'name': 'Rep. Chandra Malik',
#    'email': 'rep_malik_chandra@goyette-dickens.net',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4251,
#    'name': 'Dhananjay Johar',
#    'email': 'dhananjay_johar@ritchie.name',
#    'gender': 'male',
#    'status': 'inactive'},
#   {'id': 4250,
#    'name': 'Ameyatma Kocchar',
#    'email': 'kocchar_ameyatma@borer-dicki.biz',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4247,
#    'name': 'Chandira Singh',
#    'email': 'chandira_singh@hoeger.name',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4246,
#    'name': 'Sweta Namboothiri',
#    'email': 'namboothiri_sweta@kessler.co',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 4245,
#    'name': 'Charak Khatri',
#    'email': 'khatri_charak@berge.biz',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 4244,
#    'name': 'Sarala Mehrotra',
#    'email': 'sarala_mehrotra@schuppe.name',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 4242,
#    'name': 'Som Mukhopadhyay',
#    'email': 'som_mukhopadhyay@shanahan-spinka.org',
#    'gender': 'female',
#    'status': 'active'}]}

# %%
employees["data"]
# Out:
# [{'id': 4270,
#   'name': 'Aadinath Tandon',
#   'email': 'tandon_aadinath@emmerich-leffler.name',
#   'gender': 'female',
#   'status': 'inactive'},
#  {'id': 4269,
#   'name': 'Deb Chopra',
#   'email': 'deb_chopra@haag.info',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 4267,
#   'name': 'Dayaamay Agarwal',
#   'email': 'agarwal_dayaamay@lubowitz-steuber.info',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 4266,
#   'name': 'Gurdev Verma',
#   'email': 'verma_gurdev@deckow.info',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 4264,
#   'name': 'Chandrabhan Varrier',
#   'email': 'varrier_chandrabhan@buckridge.org',
#   'gender': 'male',
#   'status': 'inactive'},
#  {'id': 4263,
#   'name': 'Gov. Aasa Johar',
#   'email': 'gov_aasa_johar@jaskolski.name',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 4260,
#   'name': 'Chitrali Ahuja',
#   'email': 'chitrali_ahuja@schulist-mitchell.io',
#   'gender': 'male',
#   'status': 'inactive'},
#  {'id': 4259,
#   'name': 'Jay Panicker',
#   'email': 'jay_panicker@cartwright-wisozk.co',
#   'gender': 'male',
#   'status': 'inactive'},
#  {'id': 4257,
#   'name': 'Chidaakaash Asan',
#   'email': 'chidaakaash_asan@hammes.info',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 4256,
#   'name': 'Giri Saini',
#   'email': 'giri_saini@becker.org',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 4254,
#   'name': 'Brahmdev Khanna',
#   'email': 'brahmdev_khanna@sawayn.org',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 4253,
#   'name': 'Sitara Pilla',
#   'email': 'pilla_sitara@rempel.info',
#   'gender': 'female',
#   'status': 'inactive'},
#  {'id': 4252,
#   'name': 'Rep. Chandra Malik',
#   'email': 'rep_malik_chandra@goyette-dickens.net',
#   'gender': 'female',
#   'status': 'inactive'},
#  {'id': 4251,
#   'name': 'Dhananjay Johar',
#   'email': 'dhananjay_johar@ritchie.name',
#   'gender': 'male',
#   'status': 'inactive'},
#  {'id': 4250,
#   'name': 'Ameyatma Kocchar',
#   'email': 'kocchar_ameyatma@borer-dicki.biz',
#   'gender': 'female',
#   'status': 'inactive'},
#  {'id': 4247,
#   'name': 'Chandira Singh',
#   'email': 'chandira_singh@hoeger.name',
#   'gender': 'female',
#   'status': 'inactive'},
#  {'id': 4246,
#   'name': 'Sweta Namboothiri',
#   'email': 'namboothiri_sweta@kessler.co',
#   'gender': 'female',
#   'status': 'inactive'},
#  {'id': 4245,
#   'name': 'Charak Khatri',
#   'email': 'khatri_charak@berge.biz',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 4244,
#   'name': 'Sarala Mehrotra',
#   'email': 'sarala_mehrotra@schuppe.name',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 4242,
#   'name': 'Som Mukhopadhyay',
#   'email': 'som_mukhopadhyay@shanahan-spinka.org',
#   'gender': 'female',
#   'status': 'active'}]

# %% [markdown]
# ## Organize Data into Acceptible Format

# %%
    for e in employees["data"]:
        print(e["id"],'|',e["name"],"|",e["email"],"|",e["gender"],"|",1 if e["status"] == "active" else 0 )
# Out:
# 4270 | Aadinath Tandon | tandon_aadinath@emmerich-leffler.name | female | 0
# 4269 | Deb Chopra | deb_chopra@haag.info | female | 1
# 4267 | Dayaamay Agarwal | agarwal_dayaamay@lubowitz-steuber.info | male | 1
# 4266 | Gurdev Verma | verma_gurdev@deckow.info | male | 1
# 4264 | Chandrabhan Varrier | varrier_chandrabhan@buckridge.org | male | 0
# 4263 | Gov. Aasa Johar | gov_aasa_johar@jaskolski.name | female | 1
# 4260 | Chitrali Ahuja | chitrali_ahuja@schulist-mitchell.io | male | 0
# 4259 | Jay Panicker | jay_panicker@cartwright-wisozk.co | male | 0
# 4257 | Chidaakaash Asan | chidaakaash_asan@hammes.info | female | 1
# 4256 | Giri Saini | giri_saini@becker.org | female | 1
# 4254 | Brahmdev Khanna | brahmdev_khanna@sawayn.org | female | 1
# 4253 | Sitara Pilla | pilla_sitara@rempel.info | female | 0
# 4252 | Rep. Chandra Malik | rep_malik_chandra@goyette-dickens.net | female | 0
# 4251 | Dhananjay Johar | dhananjay_johar@ritchie.name | male | 0
# 4250 | Ameyatma Kocchar | kocchar_ameyatma@borer-dicki.biz | female | 0
# 4247 | Chandira Singh | chandira_singh@hoeger.name | female | 0
# 4246 | Sweta Namboothiri | namboothiri_sweta@kessler.co | female | 0
# 4245 | Charak Khatri | khatri_charak@berge.biz | male | 1
# 4244 | Sarala Mehrotra | sarala_mehrotra@schuppe.name | female | 1
# 4242 | Som Mukhopadhyay | som_mukhopadhyay@shanahan-spinka.org | female | 1

# %% [markdown]
# ## Reading Data and Save it into CSV FIle

# %%
with open ("employees.csv", "w" ,newline = '')as f :
    writer = csv.DictWriter( f ,fieldnames = ["id","name","email","gender","active"])
    writer.writeheader()
    
    for e in employees["data"]:
       id_ = e["id"]
       name = e["name"]
       email = e["email"]
       gender = e["gender"]
       active = True if e["status"] == "active" else False

       writer.writerow(
           {
            "id" : id_,
            "name" : name,
            "email" : email,
            "gender" : gender,
            "active" : active
             }
        )

# %% [markdown]
# ## Import Pandas to View Data

# %%
import pandas as pd

data = pd.read_csv("employees.csv")
data
# Out:
#       id                 name                                   email  gender  \
# 0   4270      Aadinath Tandon   tandon_aadinath@emmerich-leffler.name  female
# 1   4269           Deb Chopra                    deb_chopra@haag.info  female
# 2   4267     Dayaamay Agarwal  agarwal_dayaamay@lubowitz-steuber.info    male
# 3   4266         Gurdev Verma                verma_gurdev@deckow.info    male
# 4   4264  Chandrabhan Varrier       varrier_chandrabhan@buckridge.org    male
# 5   4263      Gov. Aasa Johar           gov_aasa_johar@jaskolski.name  female
# 6   4260       Chitrali Ahuja     chitrali_ahuja@schulist-mitchell.io    male
# 7   4259         Jay Panicker       jay_panicker@cartwright-wisozk.co    male
# 8   4257     Chidaakaash Asan            chidaakaash_asan@hammes.info  female
# 9   4256           Giri Saini                   giri_saini@becker.org  female
# 10  4254      Brahmdev Khanna              brahmdev_khanna@sawayn.org  female
# 11  4253         Sitara Pilla                pilla_sitara@rempel.info  female
# 12  4252   Rep. Chandra Malik   rep_malik_chandra@goyette-dickens.net  female
# 13  4251      Dhananjay Johar            dhananjay_johar@ritchie.name    male
# 14  4250     Ameyatma Kocchar        kocchar_ameyatma@borer-dicki.biz  female
# 15  4247       Chandira Singh              chandira_singh@hoeger.name  female
# 16  4246    Sweta Namboothiri            namboothiri_sweta@kessler.co  female
# 17  4245        Charak Khatri                 khatri_charak@berge.biz    male
# 18  4244      Sarala Mehrotra            sarala_mehrotra@schuppe.name  female
# 19  4242     Som Mukhopadhyay    som_mukhopadhyay@shanahan-spinka.org  female
#
#     active
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# 9     True
# 10    True
# 11   False
# 12   False
# 13   False
# 14   False
# 15   False
# 16   False
# 17    True
# 18    True
# 19    True
